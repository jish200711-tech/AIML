# %% [markdown]
# <a href="https://colab.research.google.com/github/jish200711-tech/AIML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-learn pandas numpy matplotlib seaborn openpyxl -q

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")
print("✅ Libraries loaded!")
# Out:
# ✅ Libraries loaded!

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-af9da5be-2d5c-4f58-ae0d-b73544c26bac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af9da5be-2d5c-4f58-ae0d-b73544c26bac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
filename = list(uploaded.keys())[0]
df = pd.read_excel(io.BytesIO(uploaded[filename]))

print("Shape:", df.shape)
print("\nFirst 5 rows:")
display(df.head())
print("\nData Types:")
print(df.dtypes)
print("\nMissing Values:")
print(df.isnull().sum())
print("\nBasic Statistics:")
display(df.describe())
# Out:
# Shape: (20, 3)
#
# First 5 rows:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500
# Data Types:
# Mileage          int64
# Age(yrs)         int64
# Sell Price($)    int64
# dtype: object
#
# Missing Values:
# Mileage          0
# Age(yrs)         0
# Sell Price($)    0
# dtype: int64
#
# Basic Statistics:
#             Mileage   Age(yrs)  Sell Price($)
# count     20.000000  20.000000      20.000000
# mean   59736.500000   5.150000   25197.500000
# std    20595.441825   1.785173    7834.479713
# min    22500.000000   2.000000   12000.000000
# 25%    50500.000000   4.000000   19375.000000
# 50%    59000.000000   5.000000   26050.000000
# 75%    73750.000000   6.250000   31625.000000
# max    91000.000000   8.000000   40000.000000

# %%
# Features and Target
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

print(f"✅ Train size : {X_train.shape[0]} rows")
print(f"✅ Test size  : {X_test.shape[0]} rows")
print(f"✅ Task Type  : REGRESSION (Predicting Sell Price)")
# Out:
# ✅ Train size : 16 rows
# ✅ Test size  : 4 rows
# ✅ Task Type  : REGRESSION (Predicting Sell Price)

# %%
results = []

def evaluate(name, model, X_tr, y_tr, X_te, y_te):
    model.fit(X_tr, y_tr)
    y_pred = model.predict(X_te)
    mse  = mean_squared_error(y_te, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_te, y_pred)
    r2   = r2_score(y_te, y_pred)
    print(f"\n{'='*50}\n  {name}\n{'='*50}")
    print(f"  MSE   : {mse:.2f}")
    print(f"  RMSE  : {rmse:.2f}")
    print(f"  MAE   : {mae:.2f}")
    print(f"  R²    : {r2:.4f}")
    results.append({"Model": name, "MSE": round(mse,2),
                    "RMSE": round(rmse,2), "MAE": round(mae,2),
                    "R² Score": round(r2,4)})
    return y_pred

# 1. Linear Regression
p1 = evaluate("1. Linear Regression", LinearRegression(),
              X_train, y_train, X_test, y_test)

# 2. Logistic Regression (not suited for regression — shown as note)
print(f"\n{'='*50}\n  2. Logistic Regression\n{'='*50}")
print("  ⚠️  Logistic Regression is a CLASSIFICATION algorithm.")
print("     It is NOT applicable for predicting continuous values like price.")
print("     Skipped intentionally for this regression dataset.")
results.append({"Model": "2. Logistic Regression", "MSE": "N/A",
                "RMSE": "N/A", "MAE": "N/A", "R² Score": "N/A (Classification only)"})

# 3. Decision Tree
p3 = evaluate("3. Decision Tree Regressor", DecisionTreeRegressor(random_state=42),
              X_train, y_train, X_test, y_test)

# 4. Random Forest
p4 = evaluate("4. Random Forest Regressor", RandomForestRegressor(n_estimators=100, random_state=42),
              X_train, y_train, X_test, y_test)
# Out:
# ...
#   1. Linear Regression
# ...
#   MSE   : 10120000.55
#   RMSE  : 3181.19
#   MAE   : 2967.92
#   R²    : 0.8360
#
# ...
#   2. Logistic Regression
# ...
#   ⚠️  Logistic Regression is a CLASSIFICATION algorithm.
#      It is NOT applicable for predicting continuous values like price.
#      Skipped intentionally for this regression dataset.
#
# ...
#   3. Decision Tree Regressor
# ...
#   MSE   : 9947500.00
#   RMSE  : 3153.97
#   MAE   : 3075.00
#   R²    : 0.8388
#
# ...
#   4. Random Forest Regressor
# ...
#   MSE   : 8008155.20
#   RMSE  : 2829.87
#   MAE   : 2292.94
#   R²    : 0.8702

# %%
# Table
print("\n========== FINAL COMPARISON TABLE ==========")
display(pd.DataFrame(results))

# Chart 1 — R² Score
fig, axes = plt.subplots(1, 2, figsize=(13, 5))
fig.suptitle("Car Price Prediction — Model Comparison", fontsize=14, fontweight="bold")

model_names = ["Linear\nRegression", "Decision\nTree", "Random\nForest"]
r2_vals   = [results[0]["R² Score"], results[2]["R² Score"], results[3]["R² Score"]]
rmse_vals = [results[0]["RMSE"],     results[2]["RMSE"],     results[3]["RMSE"]]
colors    = ["#4C72B0", "#55A868", "#C44E52"]

axes[0].bar(model_names, r2_vals, color=colors, edgecolor="black")
axes[0].set_title("R² Score (Higher = Better)")
axes[0].set_ylabel("R² Score")
axes[0].set_ylim(0, 1.1)
for i, v in enumerate(r2_vals):
    axes[0].text(i, v + 0.02, f"{v:.3f}", ha="center", fontweight="bold")

axes[1].bar(model_names, rmse_vals, color=colors, edgecolor="black")
axes[1].set_title("RMSE (Lower = Better)")
axes[1].set_ylabel("RMSE ($)")
for i, v in enumerate(rmse_vals):
    axes[1].text(i, v + 50, f"{v:.0f}", ha="center", fontweight="bold")

plt.tight_layout()
plt.savefig("model_comparison.png", dpi=150)
plt.show()
print("✅ Chart saved as model_comparison.png")
# Out:
# ========== FINAL COMPARISON TABLE ==========
#                         Model          MSE     RMSE      MAE  \
# 0        1. Linear Regression  10120000.55  3181.19  2967.92
# 1      2. Logistic Regression          N/A      N/A      N/A
# 2  3. Decision Tree Regressor    9947500.0  3153.97   3075.0
# 3  4. Random Forest Regressor    8008155.2  2829.87  2292.94
#
#                     R² Score
# 0                      0.836
# 1  N/A (Classification only)
# 2                     0.8388
# 3                     0.8702
# ✅ Chart saved as model_comparison.png

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
fig.suptitle("Actual vs Predicted — Sell Price ($)", fontsize=13, fontweight="bold")

for ax, preds, name in zip(axes,
    [p1, p3, p4],
    ["Linear Regression", "Decision Tree", "Random Forest"]):
    ax.scatter(y_test, preds, color="#4C72B0", edgecolors="black", alpha=0.8)
    mn, mx = min(y_test.min(), min(preds)), max(y_test.max(), max(preds))
    ax.plot([mn, mx], [mn, mx], "r--", label="Perfect Fit")
    ax.set_title(name)
    ax.set_xlabel("Actual Price ($)")
    ax.set_ylabel("Predicted Price ($)")
    ax.legend()

plt.tight_layout()
plt.savefig("actual_vs_predicted.png", dpi=150)
plt.show()
print("✅ Chart saved as actual_vs_predicted.png")
# Out:
# ✅ Chart saved as actual_vs_predicted.png
